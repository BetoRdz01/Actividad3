# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('Ventas_totales.csv') 
data
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            6
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#Realizamos una copia del dataframe
data2=data.copy()

# %%
#Sustituir valores nulos con promedio
data2["tarjetas_debito"]=data2["tarjetas_debito"].fillna(round(data2["tarjetas_debito"].mean(),1))
data2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Sustituir valores nulos con promedio
data2["salon_ventas"]=data2["salon_ventas"].fillna(round(data2["salon_ventas"].mean(),1))
data2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
data2["tarjetas_credito"] =data2["tarjetas_credito"].fillna(method="ffill") 
data2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
data2["otros_medios"] =data2["otros_medios"].fillna(method="ffill") 
data2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
data2["subtotal_ventas_alimentos_bebidas"] =data2["subtotal_ventas_alimentos_bebidas"].fillna(method="bfill") 
data2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
data2["almacen"] =data2["almacen"].fillna(method="bfill") 
data2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Sustituir valores nulos con mediana
data2["otros"]=data2["otros"].fillna(round(data2["otros"].median(),1))
data2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Sustituir valores nulos con mediana
data2["electronicos_articulos_hogar"]=data2["electronicos_articulos_hogar"].fillna(round(data2["electronicos_articulos_hogar"].median(),1))
data2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                1
# almacen                                0
# panaderia                              1
# lacteos                                1
# carnes                                 1
# verduleria_fruteria                    1
# alimentos_preparados_rotiseria         1
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           0
# ...

# %%
#Eliminamos filas con nulos
data3= data2.dropna(0)
data3
# Out:
# C:\Users\Alberto\AppData\Local\Temp\ipykernel_26644\2193115708.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   data3= data2.dropna(0)
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# 5     01/06/2017                    29132.7                    26365.4
# 6     01/07/2017                    31182.3                    27819.4
# 7     01/08/2017                    31154.9                    27394.1
# 8     01/09/2017                    30521.5                    26404.3
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %%
#####Empezamos con la eliminación de outliers
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["ventas_precios_corrientes"]) 
plt.title("Outliers de Precio Corrientes")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data3["ventas_precios_corrientes"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 209911.9083428069
# Limite inferior permitido -71393.2359290138

# %%
#Encontramos Ouliers
outliers= data3[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 42    01/07/2020                   211140.7                    50791.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 42                 81140696.22   76413721.76      4726974.457
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 42                81140696.22  24935747.29      22143208.63        29569224.4
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data4= data3[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["ventas_precios_constantes"]) 
plt.title("Outliers de Precios Constantes")
plt.show() #dibujamos el diagrama

# %%
y=data3["ventas_precios_constantes"]
Limite_Superior1= y.mean() + 3*y.std()
Limite_Inferior1= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior1)
print("Limite inferior permitido", Limite_Inferior1)
# Out:
# Limite superior permitido 40922.450865873005
# Limite inferior permitido 11690.528444471827

# %%
data4= data3[(y<=Limite_Superior1)&(y>=Limite_Inferior1)]
data4
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# 5     01/06/2017                    29132.7                    26365.4
# 6     01/07/2017                    31182.3                    27819.4
# 7     01/08/2017                    31154.9                    27394.1
# 8     01/09/2017                    30521.5                    26404.3
# 9     01/10/2017                    32446.0                    27766.7
# 10    01/11/2017                    33629.0                    28425.3
# 11    01/12/2017                    40766.3                    34084.5
# ...

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["ventas_totales_canal_venta"]) 
plt.title("Outliers de ventas_totales_canal_venta")
plt.show() #dibujamos el diagrama

# %%
y=data3["ventas_totales_canal_venta"]
Limite_Superior2= y.mean() + 3*y.std()
Limite_Inferior2= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior2)&(y>=Limite_Inferior2)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["salon_ventas"]) 
plt.title("Outliers de salon_ventas")
plt.show() #dibujamos el diagrama

# %%
y=data3["salon_ventas"]
Limite_Superior3= y.mean() + 3*y.std()
Limite_Inferior3= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior3)&(y>=Limite_Inferior3)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["canales_on_line"]) 
plt.title("Outliers de canales_on_line")
plt.show() #dibujamos el diagrama

# %%
y=data3["canales_on_line"]
Limite_Superior4= y.mean() + 3*y.std()
Limite_Inferior4= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior4)&(y>=Limite_Inferior4)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["ventas_totales_medio_pago"]) 
plt.title("Outliers de ventas_totales_medio_pago")
plt.show() #dibujamos el diagrama

# %%
y=data3["ventas_totales_medio_pago"]
Limite_Superior5= y.mean() + 3*y.std()
Limite_Inferior5= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior5)&(y>=Limite_Inferior5)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["efectivo"]) 
plt.title("Outliers de efectivo")
plt.show() #dibujamos el diagrama

# %%
y=data3["efectivo"]
Limite_Superior6= y.mean() + 3*y.std()
Limite_Inferior6= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior6)&(y>=Limite_Inferior6)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["tarjetas_debito"]) 
plt.title("Outliers de tarjetas_debito")
plt.show() #dibujamos el diagrama

# %%
y=data3["tarjetas_debito"]
Limite_Superior7= y.mean() + 3*y.std()
Limite_Inferior7= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior7)&(y>=Limite_Inferior7)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["tarjetas_credito"]) 
plt.title("Outliers de tarjetas_credito")
plt.show() #dibujamos el diagrama

# %%
y=data3["tarjetas_credito"]
Limite_Superior8= y.mean() + 3*y.std()
Limite_Inferior8= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior8)&(y>=Limite_Inferior8)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["otros_medios"]) 
plt.title("Outliers de otros_medios")
plt.show() #dibujamos el diagrama

# %%
y=data3["otros_medios"]
Limite_Superior9= y.mean() + 3*y.std()
Limite_Inferior9= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior9)&(y>=Limite_Inferior9)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["ventas_totales_grupo_articulos"]) 
plt.title("Outliers de ventas_totales_grupo_articulos")
plt.show() #dibujamos el diagrama

# %%
y=data3["ventas_totales_grupo_articulos"]
Limite_Superior10= y.mean() + 3*y.std()
Limite_Inferior10= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior10)&(y>=Limite_Inferior10)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["subtotal_ventas_alimentos_bebidas"]) 
plt.title("Outliers de subtotal_ventas_alimentos_bebidas")
plt.show() #dibujamos el diagrama

# %%
y=data3["subtotal_ventas_alimentos_bebidas"]
Limite_Superior11= y.mean() + 3*y.std()
Limite_Inferior11= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior11)&(y>=Limite_Inferior11)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["bebidas"]) 
plt.title("Outliers de bebidas")
plt.show() #dibujamos el diagrama

# %%
y=data3["bebidas"]
Limite_Superior12= y.mean() + 3*y.std()
Limite_Inferior12= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior12)&(y>=Limite_Inferior12)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["almacen"]) 
plt.title("Outliers de almacen")
plt.show() #dibujamos el diagrama

# %%
y=data3["almacen"]
Limite_Superior13= y.mean() + 3*y.std()
Limite_Inferior13= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior13)&(y>=Limite_Inferior13)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["panaderia"]) 
plt.title("Outliers de panaderia")
plt.show() #dibujamos el diagrama

# %%
y=data3["panaderia"]
Limite_Superior14= y.mean() + 3*y.std()
Limite_Inferior14= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior14)&(y>=Limite_Inferior14)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["lacteos"]) 
plt.title("Outliers de lacteos")
plt.show() #dibujamos el diagrama

# %%
y=data3["lacteos"]
Limite_Superior15= y.mean() + 3*y.std()
Limite_Inferior15= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior15)&(y>=Limite_Inferior15)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["carnes"]) 
plt.title("Outliers de carnes")
plt.show() #dibujamos el diagrama

# %%
y=data3["carnes"]
Limite_Superior16= y.mean() + 3*y.std()
Limite_Inferior16= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior16)&(y>=Limite_Inferior16)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["verduleria_fruteria"]) 
plt.title("Outliers de verduleria_fruteria")
plt.show() #dibujamos el diagrama

# %%
y=data3["verduleria_fruteria"]
Limite_Superior17= y.mean() + 3*y.std()
Limite_Inferior17= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior17)&(y>=Limite_Inferior17)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["alimentos_preparados_rotiseria"]) 
plt.title("Outliers de alimentos_preparados_rotiseria")
plt.show() #dibujamos el diagrama

# %%
y=data3["alimentos_preparados_rotiseria"]
Limite_Superior18= y.mean() + 3*y.std()
Limite_Inferior18= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior18)&(y>=Limite_Inferior18)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["articulos_limpieza_perfumeria"]) 
plt.title("Outliers de articulos_limpieza_perfumeria")
plt.show() #dibujamos el diagrama

# %%
y=data3["articulos_limpieza_perfumeria"]
Limite_Superior19= y.mean() + 3*y.std()
Limite_Inferior19= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior19)&(y>=Limite_Inferior19)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["indumentaria_calzado_textiles_hogar"]) 
plt.title("Outliers de indumentaria_calzado_textiles_hogar")
plt.show() #dibujamos el diagrama

# %%
y=data3["indumentaria_calzado_textiles_hogar"]
Limite_Superior20= y.mean() + 3*y.std()
Limite_Inferior20= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior20)&(y>=Limite_Inferior20)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["electronicos_articulos_hogar"]) 
plt.title("Outliers de electronicos_articulos_hogar")
plt.show() #dibujamos el diagrama

# %%
y=data3["electronicos_articulos_hogar"]
Limite_Superior21= y.mean() + 3*y.std()
Limite_Inferior21= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior21)&(y>=Limite_Inferior21)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data3["otros"]) 
plt.title("Outliers de otros")
plt.show() #dibujamos el diagrama

# %%
y=data3["otros"]
Limite_Superior22= y.mean() + 3*y.std()
Limite_Inferior22= y.mean() - 3*y.std()
data4= data3[(y<=Limite_Superior22)&(y>=Limite_Inferior22)]

# %%
data4.to_csv("Actividad3.csv")
